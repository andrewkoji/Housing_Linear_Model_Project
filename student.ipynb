# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Andrew Levinton
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name: Ahbineet Kulkarni
# * Blog post URL:

# %% [markdown]
# ## Statsmodels debug
# - This is because statsmodels was having version issues. this is a workaround
# - The code below re-publishes the existing (but private) _centered function as a public attribute to the module already imported in RAM.

# %%
import  scipy.signal.signaltools

def _centered(arr, newsize):
    # Return the center newsize portion of the array.
    newsize = np.asarray(newsize)
    currsize = np.array(arr.shape)
    startind = (currsize - newsize) // 2
    endind = startind + newsize
    myslice = [slice(startind[k], endind[k]) for k in range(len(endind))]
    return arr[tuple(myslice)]

scipy.signal.signaltools._centered = _centered

# %% [markdown]
# ## Import necessary libraries

# %%
# raw data handling
import pandas as pd
import numpy as np
import datetime as dt

# data visualiztion
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from pywaffle import Waffle
import squarify

plt.style.use('fivethirtyeight')

# regression modeling
import statsmodels.api as sm
from statsmodels.formula.api import ols

# model validation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings # weird sns.distplot() warnings
warnings.filterwarnings("ignore")

import squarify

plt.style.use('fivethirtyeight')

# %%
cd data
# Out:
# [WinError 2] The system cannot find the file specified: 'data'
# C:\Users\alevi\Documents\Flatiron\dsc-data-science-env-config\Course_Folder\Phase_2\Phase_2_Project\dsc-phase-2-project-v2-5\data

# %% [markdown]
# ## Read in dataset

# %%
df = pd.read_csv('kc_house_data.csv')
len(df)
# Out:
# 30155

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             30155 non-null  int64
#  1   date           30155 non-null  object
#  2   price          30155 non-null  float64
#  3   bedrooms       30155 non-null  int64
#  4   bathrooms      30155 non-null  float64
#  5   sqft_living    30155 non-null  int64
#  6   sqft_lot       30155 non-null  int64
#  7   floors         30155 non-null  float64
#  8   waterfront     30155 non-null  object
#  9   greenbelt      30155 non-null  object
#  10  nuisance       30155 non-null  object
#  11  view           30155 non-null  object
#  12  condition      30155 non-null  object
#  13  grade          30155 non-null  object
#  14  heat_source    30123 non-null  object
#  15  sewer_system   30141 non-null  object
#  16  sqft_above     30155 non-null  int64
#  17  sqft_basement  30155 non-null  int64
#  18  sqft_garage    30155 non-null  int64
#  19  sqft_patio     30155 non-null  int64
#  20  yr_built       30155 non-null  int64
#  21  yr_renovated   30155 non-null  int64
#  22  address        30155 non-null  object
#  23  lat            30155 non-null  float64
#  24  long           30155 non-null  float64
# dtypes: float64(5), int64(10), object(10)
# memory usage: 5.8+ MB

# %% [markdown]
# #### Simple Linear Regression on select features
# Assumption check:
# - Is it linear?
# - Is it normal?
#     - histogram
#     - QQ-plot
# - Is it homoscedastic?

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 30111

# %% [markdown]
# ## Data Preparation

# %%
# Changing grade to a float
df['grade'] = df['grade'].apply(lambda x: float(x.split(' ')[0]))

# replaces condition objects with numerics based on data dict.
condition_dict = {'Poor':1,'Fair':2,'Average':3,'Good':4,'Very Good':5}
df.condition.replace(to_replace=condition_dict,inplace=True)

# replace yr_built NaNs with numeric 0
df.yr_renovated.replace(to_replace=np.nan,value=0,inplace=True)

# convert waterfront into numeric boolean
waterfront_bool_dict = {'YES':1,'NO':0,np.nan:0}
df.waterfront.replace(to_replace=waterfront_bool_dict,inplace=True)

# convert view from string into categorical ordinal
view_dict = {np.nan:0,'NONE':0,'FAIR':1,'AVERAGE':2,'GOOD':3,'EXCELLENT':4}
df.view.replace(to_replace=view_dict,inplace=True)

# convert dates into ordinals, extrapolate month from date into new column. 
df.date = pd.to_datetime(df['date']) # convert date string into datetime object 
df['sale_month'] = df['date'].dt.month # grabbing month from date into new column
df['sale_year'] = df['date'].dt.year # grabbing year from date into new column
df.date = df['date'].map(dt.datetime.toordinal) # convert original date to ordinal
df.rename({'date':'sale_date'},axis=1,inplace=True) # rename date to 'sale_date' for readability

# %%
df['address'][0]
# Out:
# '2102 Southeast 21st Court, Renton, Washington 98055, United States'

# %% [markdown]
# ### Grabbing City

# %%
df['city'] = df['address'].apply(lambda x: x.split(',')[1])
df['city']
# Out:
# 0                          Renton
# 1                         Seattle
# 2                         Seattle
# 3                         Seattle
# 4                        Issaquah
# 5                       Shoreline
# 6                          Burien
# 7                            Kent
# 8                     Federal Way
# 9                          Duvall
# 10                        Seattle
# 11                           Kent
# 12                          Omaha
# 13                         Auburn
# 14                    Federal Way
# 15                        Seattle
# 16                       Bellevue
# 17                        Seattle
# 18                        Seattle
# 19                        Seattle
# 20                       Bellevue
# 21                   Maple Valley
# 22                         Renton
# 23                    Woodinville
# 24                        Seattle
# 25                           Kent
# 26                        Redmond
# 27                         Medina
# 28                        Seattle
# 29                       Bellevue
# 30                           Kent
# 31                        Seattle
# 32               Lake Forest Park
# 33                         SeaTac
# 34                      Shoreline
# 35                        Seattle
# 36                     Clyde Hill
# 37                     North Bend
# 38                           Kent
# 39                         Auburn
# 40                         Renton
# 41                        Redmond
# 42                       Bellevue
# 43                        Bothell
# 44                       Bellevue
# 45                         Auburn
# 46                        Seattle
# 47               Lake Forest Park
# 48                           Kent
# 49                         Duvall
# 50                       Kirkland
# 51                        Seattle
# 52                         Burien
# 53                       Vineland
# 54                        Seattle
# 55                     Des Moines
# 56                         Auburn
# 57                        Seattle
# 58                         Auburn
# 59                    Federal Way
# 60                       Bellevue
# 61                        Seattle
# 62                    McLeansboro
# 63                        Redmond
# 64                        Seattle
# 65                       Kirkland
# 66                       Issaquah
# 67                         Renton
# 68                         Renton
# 69                       Kirkland
# 70                        Seattle
# 71                      Newcastle
# 72                       Bellevue
# 73                       Kirkland
# 74                  Mercer Island
# 75                     North Bend
# 76                        Redmond
# 77                      Carnation
# 78                        Seattle
# 79                        Redmond
# 80                           Kent
# 81                         Burien
# 82                        Seattle
# 83                        Seattle
# 84                        Seattle
# 85               Lake Forest Park
# 86                      Sammamish
# 87                        Seattle
# 88                        Seattle
# 89                    Federal Way
# 90                         Auburn
# 91                        Seattle
# 92                        Seattle
# 93                           Kent
# 94                        Seattle
# 95                        Redmond
# 96                        Seattle
# 97                        Seattle
# 98                       Issaquah
# 99                           Kent
# 100                   Federal Way
# 101                        Duvall
# 102                      Issaquah
# 103                       Seattle
# 104                       Seattle
# 105                       Seattle
# 106                       Seattle
# 107                    Snoqualmie
# 108                   Federal Way
# 109                      Enumclaw
# 110                   Woodinville
# 111                        Renton
# 112                        Auburn
# 113                       Seattle
# 114                     Covington
# 115                       Seattle
# 116                     Shoreline
# 117                        Renton
# 118                        Medina
# 119                        Burien
# 120                        Auburn
# 121                        Renton
# 122                          Kent
# 123                   Federal Way
# 124                        Renton
# 125                       Redmond
# 126                          Kent
# 127                          Kent
# 128                       Seattle
# 129                          Kent
# 130                       Seattle
# 131                      Kirkland
# 132                       Seattle
# 133                        Auburn
# 134                     Newcastle
# 135                        Burien
# 136                      Issaquah
# 137                        Auburn
# 138                       Seattle
# 139                       Seattle
# 140                    Clyde Hill
# 141                  Maple Valley
# 142                      Kirkland
# 143                       Seattle
# 144                      Bellevue
# 145                       Seattle
# 146                      Kirkland
# 147                     Sammamish
# 148                       Seattle
# 149                       Seattle
# 150                       Seattle
# 151                  Maple Valley
# 152                       Seattle
# 153                     Newcastle
# 154                     Fall City
# 155                     Shoreline
# 156                  Maple Valley
# 157                       Seattle
# 158                   Federal Way
# 159                    Union City
# 160                        Burien
# 161                      Bellevue
# 162                        Renton
# 163                       Seattle
# 164                  Maple Valley
# 165                     Shoreline
# 166                       Seattle
# 167                       Seattle
# 168                       Seattle
# 169                       Seattle
# 170                       Seattle
# 171                       Seattle
# 172                  West Babylon
# 173                     Sammamish
# 174                    North Bend
# 175                   Federal Way
# 176                  Maple Valley
# 177                       Redmond
# 178                       Redmond
# 179                   Woodinville
# 180                  Maple Valley
# 181                       Seattle
# 182                       Seattle
# 183                  Maple Valley
# 184                        Auburn
# 185                          Kent
# 186                    Snoqualmie
# 187                        Renton
# 188                       Seattle
# 189                       Seattle
# 190                      Kirkland
# 191                       Seattle
# 192                       Redmond
# 193                        Auburn
# 194                     Newcastle
# 195                       Seattle
# 196                      Bellevue
# 197                       Seattle
# 198                       Seattle
# 199                      Enumclaw
# 200                          Kent
# 201                        Renton
# 202                       Seattle
# 203                       Redmond
# 204                        Renton
# 205                       Seattle
# 206                       Seattle
# 207                       Seattle
# 208                      Bellevue
# 209                    Clyde Hill
# 210                        Renton
# 211                        SeaTac
# 212                       Seattle
# 213                       Seattle
# 214                       Seattle
# 215                       Seattle
# 216                        Renton
# 217                       Seattle
# 218                       Seattle
# 219                  Maple Valley
# 220                       Seattle
# 221                        Auburn
# 222                       Seattle
# 223                        Auburn
# 224                       Seattle
# 225                       Seattle
# 226                    Snoqualmie
# 227                   Woodinville
# 228                     Sammamish
# 229                        Renton
# 230                   Federal Way
# 231                       Redmond
# 232                       Seattle
# 233                  Cedar Rapids
# 234                    North Bend
# 235                    Des Moines
# 236                      Scituate
# 237                     Covington
# 238                       Seattle
# 239                      Longmont
# 240                       Seattle
# 241                     Sammamish
# 242                      Bellevue
# 243                   Woodinville
# 244                   Federal Way
# 245                   North Hills
# 246                    North Bend
# 247                        Renton
# 248                       Seattle
# 249                      Bellevue
# 250                       Seattle
# 251                     Sammamish
# 252                        Burien
# 253                       Seattle
# 254                       Seattle
# 255                     Newcastle
# 256                       Redmond
# 257                       Seattle
# 258                       Redmond
# 259                       Seattle
# 260                       Seattle
# 261                          Kent
# 262                       Seattle
# 263                       Seattle
# 264                       Seattle
# 265                          Kent
# 266                        Duvall
# 267                      Kirkland
# 268                       Seattle
# 269                     Shoreline
# 270                     Newcastle
# 271                       Seattle
# 272                        Renton
# 273                      Enumclaw
# 274                        Auburn
# 275                          Kent
# 276                      Kirkland
# 277                    Snoqualmie
# 278                       Bothell
# 279                 Normandy Park
# 280                       Seattle
# 281                     Newcastle
# 282                    Des Moines
# 283                       Seattle
# 284                      Bellevue
# 285                       Seattle
# 286                       Seattle
# 287                       Seattle
# 288                       Seattle
# 289                      Bellevue
# 290                  Maple Valley
# 291                       Seattle
# 292                   Federal Way
# 293                       Seattle
# 294                      Kirkland
# 295                       Seattle
# 296                   Federal Way
# 297                        Renton
# 298                  Philadelphia
# 299                          Kent
# 300                       Seattle
# 301                      Kirkland
# 302                     Carnation
# 303                          Kent
# 304                      Enumclaw
# 305                        Algona
# 306                       Seattle
# 307                       Kenmore
# 308                        Renton
# 309                     Carnation
# 310                          Kent
# 311                       Seattle
# 312                   Woodinville
# 313                      Bellevue
# 314                        Renton
# 315                    North Bend
# 316                       Seattle
# 317                        Burien
# 318                        Auburn
# 319                       Seattle
# 320                       Redmond
# 321                        Renton
# 322                          Kent
# 323                       Seattle
# 324                       Kenmore
# 325                    Snoqualmie
# 326                       Seattle
# 327                      Enumclaw
# 328                      Bellevue
# 329                        Duvall
# 330                       Seattle
# 331                       Seattle
# 332                       Seattle
# 333                        SeaTac
# 334                   Minneapolis
# 335                       Seattle
# 336                 Normandy Park
# 337                      Kirkland
# 338                      Bellevue
# 339                       Seattle
# 340                       Seattle
# 341                        Renton
# 342                      Kirkland
# 343                     Shoreline
# 344                       Tukwila
# 345                    North Bend
# 346                       Seattle
# 347                        Auburn
# 348                     Shoreline
# 349                       Seattle
# 350                     Sammamish
# 351                       Seattle
# 352                       Redmond
# 353                    Des Moines
# 354                       Tukwila
# 355                     Sammamish
# 356                      Kirkland
# 357                        Auburn
# 358                        Auburn
# 359                       Redmond
# 360                       Seattle
# 361                    Snoqualmie
# 362                   Woodinville
# 363                       Seattle
# 364                     Sammamish
# 365                       Seattle
# 366                        Renton
# 367                        Duvall
# 368                       Seattle
# 369                     Sammamish
# 370                   Federal Way
# 371                       Seattle
# 372                     Sammamish
# 373                       Seattle
# 374                   Federal Way
# 375                    North Bend
# 376                     Newcastle
# 377                        Renton
# 378                       Bothell
# 379                        SeaTac
# 380                        SeaTac
# 381                      Issaquah
# 382                        Renton
# 383                     Sammamish
# 384                     Sammamish
# 385                     Newcastle
# 386                 Mercer Island
# 387                 Black Diamond
# 388                    Des Moines
# 389                       Seattle
# 390                        Burien
# 391                  Maple Valley
# 392                     Covington
# 393                     Carnation
# 394                        Renton
# 395                     Covington
# 396                     Shoreline
# 397              Pleasant Prairie
# 398                        Renton
# 399                 Mercer Island
# 400                       Seattle
# 401                       Seattle
# 402                       Pacific
# 403                   Woodinville
# 404                      Bellevue
# 405                       Seattle
# 406                      Bellevue
# 407                        Auburn
# 408                      Enumclaw
# 409                       Seattle
# 410                       Seattle
# 411                       Bothell
# 412                       Seattle
# 413                       Seattle
# 414                       Redmond
# 415                      Enumclaw
# 416                       Seattle
# 417                        Renton
# 418                       Seattle
# 419                     Shoreline
# 420                       Seattle
# 421                West Homestead
# 422                       Seattle
# 423                      Bellevue
# 424                       Redmond
# 425                     Sammamish
# 426                       Seattle
# 427                       Seattle
# 428                          Kent
# 429                        Algona
# 430                       Kenmore
# 431                      Bellevue
# 432                       Seattle
# 433                  Maple Valley
# 434                  Maple Valley
# 435                      Enumclaw
# 436                      Bellevue
# 437                       Seattle
# 438                      Bellevue
# 439                       Seattle
# 440                       Seattle
# 441                     Shoreline
# 442                       Seattle
# 443                     Shoreline
# 444                        Renton
# 445                      Issaquah
# 446                       Seattle
# 447                       Seattle
# 448                        Renton
# 449                  Maple Valley
# 450                       Seattle
# 451                   Federal Way
# 452                        Renton
# 453                       Seattle
# 454                      Enumclaw
# 455                       Seattle
# 456                        Renton
# 457                       Seattle
# 458                        Renton
# 459                       Seattle
# 460                        Auburn
# 461                     Sammamish
# 462                          Kent
# 463                       Kenmore
# 464                     Fall City
# 465                      Kirkland
# 466                       Seattle
# 467                        Renton
# 468                       Seattle
# 469                       Seattle
# 470               721 NW 21st Ave
# 471                        Duvall
# 472                      Enumclaw
# 473                       Seattle
# 474                       Bothell
# 475                       Seattle
# 476                       Seattle
# 477                        Vashon
# 478                       Kenmore
# 479              Lake Forest Park
# 480                       Seattle
# 481                      Issaquah
# 482                       Seattle
# 483                       Seattle
# 484                        Auburn
# 485                      Enumclaw
# 486                        Algona
# 487                    North Bend
# 488                       Seattle
# 489                       Seattle
# 490                      Kirkland
# 491                     Carnation
# 492                          Kent
# 493                       Seattle
# 494                     Newcastle
# 495                       Seattle
# 496                       Seattle
# 497                       Seattle
# 498                       Seattle
# 499                    North Bend
# 500                       Seattle
# 501                        Auburn
# 502                     Carnation
# 503                       Seattle
# 504                        Burien
# 505                  Maple Valley
# 506                        Vashon
# 507                      Kirkland
# 508                   Federal Way
# 509                        Auburn
# 510                       Seattle
# 511                        Queens
# 512                  Maple Valley
# 513                       Seattle
# 514                       Seattle
# 515                        Renton
# 516                   Woodinville
# 517                       Seattle
# 518                        Burien
# 519                          Kent
# 520                  Maple Valley
# 521                       Seattle
# 522                        Auburn
# 523                       Seattle
# 524                      Issaquah
# 525                       Seattle
# 526                      Bellevue
# 527                       Seattle
# 528                          Kent
# 529                 Mercer Island
# 530                        Auburn
# 531                       Seattle
# 532                          Kent
# 533                       Seattle
# 534                     Sammamish
# 535                       Seattle
# 536                       Seattle
# 537                       Tukwila
# 538                       Seattle
# 539                      Kirkland
# 540                       Seattle
# 541                          Kent
# 542                       Seattle
# 543                      Bellevue
# 544                       Kenmore
# 545                       Seattle
# 546                    Clyde Hill
# 547                     Sammamish
# 548                        Burien
# 549                     Sammamish
# 550                        Renton
# 551                       Seattle
# 552                       Seattle
# 553                      Scituate
# 554                      Kirkland
# 555                     Covington
# 556                 Mercer Island
# 557                       Seattle
# 558                       Seattle
# 559                        Auburn
# 560                   Federal Way
# 561                     Shoreline
# 562                       Seattle
# 563                          Kent
# 564                       Redmond
# 565                       Seattle
# 566                        Auburn
# 567                          Kent
# 568                     Covington
# 569                       Redmond
# 570                       Seattle
# 571                        Auburn
# 572                        Auburn
# 573                       Seattle
# 574                       Seattle
# 575                       Seattle
# 576                      Bellevue
# 577                 Black Diamond
# 578                          Kent
# 579                        Burien
# 580                  Maple Valley
# 581                       Seattle
# 582                     Shoreline
# 583                          Kent
# 584                       Seattle
# 585                       Seattle
# 586                       Seattle
# 587                    Snoqualmie
# 588                       Seattle
# 589                     Sammamish
# 590                       Kenmore
# 591                   Woodinville
# 592                       Seattle
# 593                   Federal Way
# 594                      Kirkland
# 595                       Seattle
# 596                       Seattle
# 597                       Seattle
# 598                    Des Moines
# 599                        Renton
# 600                       Seattle
# 601                       Bothell
# 602                          Kent
# 603                       Seattle
# 604                   Woodinville
# 605                 Black Diamond
# 606                      Bellevue
# 607                       Seattle
# 608                       Seattle
# 609                      Issaquah
# 610                       Seattle
# 611                        Auburn
# 612                       Seattle
# 613                   Woodinville
# 614                       Seattle
# 615                      Issaquah
# 616                       Seattle
# 617                 Mercer Island
# 618                       Seattle
# 619                   Federal Way
# 620                     Shoreline
# 621                     Newcastle
# 622                       Seattle
# 623                        Renton
# 624                          Kent
# 625                       Tukwila
# 626                    Clyde Hill
# 627                          Kent
# 628                       Seattle
# 629                   Woodinville
# 630                 Mercer Island
# 631                       Seattle
# 632                    Snoqualmie
# 633                       Seattle
# 634                       Kenmore
# 635                    Clyde Hill
# 636                   Federal Way
# 637                      Bellevue
# 638                       Seattle
# 639                        Renton
# 640                       Seattle
# 641                     Fall City
# 642                      Issaquah
# 643                       Seattle
# 644                  Maple Valley
# 645                          Kent
# 646                        Burien
# 647                     Sammamish
# 648                    Des Moines
# 649                     Sammamish
# 650                      Bellevue
# 651                        Renton
# 652                    North Bend
# 653                       Seattle
# 654                       Redmond
# 655                     Sammamish
# 656                    North Bend
# 657                       Seattle
# 658                       Seattle
# 659                        Renton
# 660                        Auburn
# 661                        SeaTac
# 662                          Kent
# 663                   Woodinville
# 664                        Renton
# 665                        Renton
# 666                       Seattle
# 667                   Federal Way
# 668                 Mercer Island
# 669                       Seattle
# 670                        Vashon
# 671                   Federal Way
# 672                       Seattle
# 673                        Auburn
# 674                   Federal Way
# 675                      Kirkland
# 676                          Kent
# 677                        Renton
# 678                       Seattle
# 679                        Renton
# 680                       Seattle
# 681                        SeaTac
# 682                       Seattle
# 683                          Kent
# 684                       Seattle
# 685                       Redmond
# 686                        Renton
# 687                  Maple Valley
# 688                      Kirkland
# 689                        Auburn
# 690                      Kirkland
# 691                        Burien
# 692                      Enumclaw
# 693                      Bellevue
# 694                      Kirkland
# 695                          Kent
# 696                        Auburn
# 697                      Issaquah
# 698                        Auburn
# 699                       Seattle
# 700                    Des Moines
# 701                        Auburn
# 702                      Bellevue
# 703                       Seattle
# 704                      Issaquah
# 705                       Seattle
# 706                        Renton
# 707                      Bellevue
# 708                       Seattle
# 709                    Des Moines
# 710                   Federal Way
# 711             108 Foothill Blvd
# 712                        Burien
# 713                          Kent
# 714                      Bellevue
# 715                     Sammamish
# 716                     Fall City
# 717                        Renton
# 718                       Seattle
# 719                       Seattle
# 720                       Seattle
# 721                      Kirkland
# 722                        Auburn
# 723                        Renton
# 724                     Covington
# 725                       Seattle
# 726                     Shoreline
# 727                      Enumclaw
# 728                      Enumclaw
# 729                       Redmond
# 730                      Bellevue
# 731                        Renton
# 732                 Nebraska City
# 733                       Seattle
# 734                       Seattle
# 735                        Auburn
# 736                   Federal Way
# 737                          Kent
# 738                       Seattle
# 739                       Seattle
# 740                  Maple Valley
# 741                     Sammamish
# 742                        Burien
# 743                       Seattle
# 744                       Seattle
# 745                        Renton
# 746                       Seattle
# 747                       Kenmore
# 748                      Issaquah
# 749                     Sammamish
# 750                      Bellevue
# 751                      Kirkland
# 752                       Seattle
# 753                       Bothell
# 754                       Seattle
# 755                      Bellevue
# 756                        Renton
# 757                       Seattle
# 758                        Renton
# 760                      Bellevue
# 761                   Federal Way
# 762                        Medina
# 763                   Federal Way
# 764                          Kent
# 765                    North Bend
# 766                          Kent
# 767                       Kenmore
# 768                       Seattle
# 769                    Des Moines
# 770                       Redmond
# 771                       Redmond
# 772                       Seattle
# 773                     Covington
# 774                        Renton
# 775                       Seattle
# 776                     Newcastle
# 777                  Maple Valley
# 778                    Des Moines
# 779                        Auburn
# 780                       Seattle
# 781                       Seattle
# 782                       Seattle
# 783                      Kirkland
# 784                    Des Moines
# 785                          Kent
# 786                  Maple Valley
# 787                   Federal Way
# 788                      Bellevue
# 789                       Seattle
# 790                       Seattle
# 791                          Kent
# 792                   Woodinville
# 793                       Seattle
# 794                       Seattle
# 795                          Kent
# 796                       Kenmore
# 797                  Maple Valley
# 798                    Snoqualmie
# 799                      Bellevue
# 800                       Seattle
# 801                      Kirkland
# 802                    Snoqualmie
# 803                  Maple Valley
# 804                       Seattle
# 805                       Seattle
# 806                     Sammamish
# 807                  Maple Valley
# 808                       Seattle
# 809                     Covington
# 810                       Seattle
# 811                      Bellevue
# 812                      Kirkland
# 813                          Kent
# 814                       Tukwila
# 815                    Litchville
# 816                        Renton
# 817                       Seattle
# 818                     Shoreline
# 819                      Kirkland
# 820                   Woodinville
# 821                      Issaquah
# 822                  Maple Valley
# 823                     Sammamish
# 824                       Seattle
# 825                     Shoreline
# 826                 Mercer Island
# 827                        Medina
# 828                        Auburn
# 829                      Issaquah
# 830                          Kent
# 831                       Seattle
# 832                       Seattle
# 833                        Auburn
# 834                      Bellevue
# 835                          Kent
# 836                      Kirkland
# 837                       Seattle
# 838                       Seattle
# 839                      Bellevue
# 840                      Issaquah
# 841                        Burien
# 842                       Seattle
# 843                      Bellevue
# 844                    Des Moines
# 845                   Federal Way
# 846                      Bellevue
# 847                      Kirkland
# 848                       Kenmore
# 849                  Maple Valley
# 850                 Black Diamond
# 851                        Renton
# 852                        Renton
# 853                      Scituate
# 854                        Vashon
# 855                   Plattsmouth
# 856                          Kent
# 857                       Seattle
# 858                    North Bend
# 859                          Kent
# 860                     Fall City
# 861                          Kent
# 862                    North Bend
# 863                        Medina
# 864                        Auburn
# 865                       Seattle
# 866                       Seattle
# 867                       Seattle
# 868                          Kent
# 869                   Federal Way
# 870                        Renton
# 871                    Snoqualmie
# 872                       Seattle
# 873                        Auburn
# 874                     Sammamish
# 875                     Newcastle
# 876                 Mercer Island
# 877                   Federal Way
# 878                       Kenmore
# 879                       Seattle
# 880                      Bellevue
# 881                    Des Moines
# 882                        Auburn
# 883                     Sammamish
# 884                   Federal Way
# 885                          Kent
# 886                       Seattle
# 887                      Issaquah
# 888                       Bothell
# 889                       Seattle
# 890                        Auburn
# 891                          Kent
# 892                       Seattle
# 893                   Federal Way
# 894                       Seattle
# 895                  Maple Valley
# 896                       Seattle
# 897                        Auburn
# 898                        Vashon
# 899                       Seattle
# 900                      Kirkland
# 901                      Kirkland
# 902                          Kent
# 903                   Federal Way
# 904                   Federal Way
# 906                      Enumclaw
# 907                       Seattle
# 908                       Redmond
# 909                     Sammamish
# 910                       Seattle
# 911                        Renton
# 912                       Seattle
# 913                       Seattle
# 914                     Fall City
# 915                   Federal Way
# 916                       Seattle
# 917                     Sammamish
# 918                  Maple Valley
# 919                          Kent
# 920                        Renton
# 921                       Seattle
# 922                    North Bend
# 923                   Federal Way
# 924                       Seattle
# 925                     Sammamish
# 926                       Seattle
# 927                       Seattle
# 928                     Sammamish
# 929                     Shoreline
# 930                       Seattle
# 931                       Seattle
# 932                       Seattle
# 933                       Redmond
# 934                        Auburn
# 935                          Kent
# 936                       Seattle
# 937                   Springfield
# 938                   Plattsmouth
# 939                   Federal Way
# 940                    North Bend
# 941                    Snoqualmie
# 942                     Shoreline
# 943                        Vashon
# 944                       Seattle
# 945                      Columbus
# 946                        Renton
# 947                          Kent
# 948                        Renton
# 949                     Newcastle
# 950                        Renton
# 951                          Kent
# 952                        Vashon
# 953                 Black Diamond
# 954                        Auburn
# 955                 Black Diamond
# 956                       Seattle
# 957                       Seattle
# 958                      Rockford
# 959                      Bellevue
# 960                      Honolulu
# 961                     Sammamish
# 962                          Kent
# 963                 Normandy Park
# 964                      Bellevue
# 965                          Kent
# 966                      Enumclaw
# 967                       Seattle
# 968                      Bellevue
# 969                        Burien
# 970                     Carnation
# 971                       Seattle
# 972                       Seattle
# 973                    Des Moines
# 974                       Seattle
# 975                        Auburn
# 976                          Kent
# 977                        Duvall
# 978                   Federal Way
# 1384                Mercer Island
# 1385                       Renton
# 1386                       Renton
# 1387                Mercer Island
# 1388                    Covington
# 1389                Black Diamond
# 1390                North Liberty
# 1391                Mercer Island
# 1392                   Des Moines
# 1393                  Federal Way
# 1394                       Golden
# 1395                      Seattle
# 1396                 Maple Valley
# 1397                      Seattle
# 1398                       Auburn
# 1399                      Bothell
# 1400                       Duvall
# 1401                      Bothell
# 1402                      Seattle
# 1403                    Sammamish
# 1404                  Woodinville
# 1405                       Renton
# 1406                     Kirkland
# 1407                   North Bend
# 1408                      Seattle
# 1409                    Shoreline
# 1410                      Seattle
# 1411                    Newcastle
# 1412                    Sammamish
# 1413                      Seattle
# ...
# 29686                   Shoreline
# 29687                     Seattle
# 29688                 Federal Way
# 29689                      Burien
# 29690                      Duvall
# 29691                  North Bend
# 29692                     Seattle
# 29693                      Renton
# 29694                Maple Valley
# 29695                      Auburn
# 29696                   Newcastle
# 29697                     Seattle
# 29698                Maple Valley
# 29699                   Fall City
# 29700                     Seattle
# 29701                Maple Valley
# 29702                      Auburn
# 29703                     Seattle
# 29704                     Seattle
# 29705                    Kirkland
# 29706                 Federal Way
# 29707                   Fall City
# 29708                        Kent
# 29709                   Shoreline
# 29710                        Kent
# 29711                     Seattle
# 29712                     Seattle
# 29713                   Shoreline
# 29714                     Pacific
# 29715                      Auburn
# 29716                     Seattle
# 29717                     Seattle
# 29718                        Kent
# 29719                 Woodinville
# 29720                        Kent
# 29721                     Seattle
# 29722                Maple Valley
# 29723                        Mesa
# 29724                     Seattle
# 29725                     Seattle
# 29726                     Seattle
# 29727                     Seattle
# 29728                    Bellevue
# 29729                    Bellevue
# 29730                Maple Valley
# 29731                    Kirkland
# 29732               Black Diamond
# 29733                     Seattle
# 29734                  North Bend
# 29735                      Duvall
# 29736                        Kent
# 29737                      Renton
# 29738               Normandy Park
# 29739                      Burien
# 29740               Black Diamond
# 29741                   Newcastle
# 29742                   Newcastle
# 29743                    Enumclaw
# 29744                     Seattle
# 29745                      Renton
# 29746                     Seattle
# 29747                  North Bend
# 29748                     Seattle
# 29749                     Seattle
# 29750                      Renton
# 29751                    Kirkland
# 29752                     Seattle
# 29753                     Seattle
# 29754                        Kent
# 29755                    Issaquah
# 29756                      Renton
# 29757                     Redmond
# 29758                     Seattle
# 29759               Normandy Park
# 29760                        Kent
# 29761                     Seattle
# 29762                     Redmond
# 29763                     Redmond
# 29764                      Renton
# 29765                     Seattle
# 29766                     Redmond
# 29767                     Seattle
# 29768                   Shoreline
# 29769                    Kirkland
# 29770                      Renton
# 29771                    Issaquah
# 29772                      Burien
# 29773                        Kent
# 29774                     Seattle
# 29775                     Seattle
# 29776                      Duvall
# 29777                      Renton
# 29778                     Redmond
# 29779                  Snoqualmie
# 29780                        Kent
# 29781                      Auburn
# 29782                   Carnation
# 29783                     Seattle
# 29784                    Bellevue
# 29785                   Shoreline
# 29786                Maple Valley
# 29787                  Snoqualmie
# 29788                Seaside Park
# 29789                    Kirkland
# 29790                      Renton
# 29926                      Burien
# 29927                     Pacific
# 29928                      Auburn
# 29929                      Renton
# 29930                  Des Moines
# 29931                    Kirkland
# 29932                     Seattle
# 29933                        Kent
# 29934                      Auburn
# 29935                 Woodinville
# 29936                    Bellevue
# 29937                     Redmond
# 29938                     Seattle
# 29939                Maple Valley
# 29940                      Renton
# 29941                      Algona
# 29942                     Seattle
# 29943                    Bellevue
# 29944                     Seattle
# 29945                 Federal Way
# 29946                     Seattle
# 29947                    Kirkland
# 29948                 Federal Way
# 29949                     Seattle
# 29950                     Seattle
# 29951                    Enumclaw
# 29952                  Des Moines
# 29953                        Kent
# 29954                     Bothell
# 29955                    Bellevue
# 29956                     Seattle
# 29957                  Ravensdale
# 29958                     Redmond
# 29959                     Seattle
# 29960                  North Bend
# 29961                     Redmond
# 29962                      Auburn
# 29963                   Shoreline
# 29964                     Pacific
# 29965                      Renton
# 29966                      Renton
# 29967                    Issaquah
# 29968                   Vancouver
# 29969                   Shoreline
# 29970                 Woodinville
# 29971                     Seattle
# 29972                     Seattle
# 29973                     Seattle
# 29974                    Bellevue
# 29975                     Seattle
# 29976                     Seattle
# 29977                     Seattle
# 29978                Saint Albans
# 29979                      Renton
# 29980                 East Moline
# 29981                    Kirkland
# 29982                    Bellevue
# 29983                  Ravensdale
# 29984                        Kent
# 29985                      Vashon
# 29986                     Seattle
# 29987                   Sammamish
# 29988                     Seattle
# 29989                     Seattle
# 29990                      Auburn
# 29991                     Seattle
# 29992                   Sammamish
# 29993               Mercer Island
# 29994                   Covington
# 29995                   Sammamish
# 29996                     Redmond
# 29997                    Kirkland
# 29998                     Kenmore
# 29999                     Seattle
# 30000                Maple Valley
# 30001                      Auburn
# 30002                     Redmond
# 30003                  North Bend
# 30004                   Sammamish
# 30005                   Shoreline
# 30006                     Seattle
# 30007                        Kent
# 30008                     Redmond
# 30009                     Seattle
# 30010                      Renton
# 30011                   Covington
# 30012                     Seattle
# 30013                     Seattle
# 30014                     Bothell
# 30015                     Redmond
# 30016                    Kirkland
# 30017                        Kent
# 30018                    Issaquah
# 30019                     Chicago
# 30020                    Kirkland
# 30021                     Seattle
# 30022               Nebraska City
# 30023                     Seattle
# 30024                 Federal Way
# 30025                     Seattle
# 30026                     Redmond
# 30027                    Issaquah
# 30028                   Shoreline
# 30029                 34 Ridge Rd
# 30030                    Bellevue
# 30031                      SeaTac
# 30032                     Seattle
# 30033                    Bellevue
# 30034                  Des Moines
# 30035                     Seattle
# 30036                     Seattle
# 30037                Maple Valley
# 30038                    Bellevue
# 30039                     Seattle
# 30040                    Enumclaw
# 30041                     Seattle
# 30042                     Seattle
# 30043                     Seattle
# 30044                     Kenosha
# 30045                   Covington
# 30046                    Bellevue
# 30047                      Renton
# 30048                   Sammamish
# 30049                     Seattle
# 30050                        Kent
# 30051                   Shoreline
# 30052                     Seattle
# 30053                      Auburn
# 30054                   Sammamish
# 30055                     Seattle
# 30056            Lake Forest Park
# 30057                 Federal Way
# 30058                     Seattle
# 30059                        Kent
# 30060                     Seattle
# 30061                    Enumclaw
# 30062                     Seattle
# 30063                 Woodinville
# 30064               Mercer Island
# 30065                     Seattle
# 30066                Maple Valley
# 30067                    Kirkland
# 30068                     Seattle
# 30069                     Redmond
# 30070                Maple Valley
# 30071                      Vashon
# 30072                      Renton
# 30073                    Bellevue
# 30074                     Kenmore
# 30075                  Des Moines
# 30076                      Auburn
# 30077                      Renton
# 30078                 Woodinville
# 30079                     Bothell
# 30080                        Kent
# 30081                     Seattle
# 30082                      Renton
# 30083                     Seattle
# 30084                     Seattle
# 30085                     Seattle
# 30086                     Seattle
# 30087                    Kirkland
# 30088                        Kent
# 30089                     Seattle
# 30090                    Kirkland
# 30091                      Burien
# 30092                     Seattle
# 30093                 Federal Way
# 30094                     Seattle
# 30095                  North Bend
# 30096                     Redmond
# 30097                    Bellevue
# 30098                    Kirkland
# 30099                     Seattle
# 30100                   Sammamish
# 30101                   Shoreline
# 30102                 Woodinville
# 30103                Maple Valley
# 30104            Lake Forest Park
# 30105                     Seattle
# 30106                     Seattle
# 30107                     Seattle
# 30108                    Bellevue
# 30109                      Auburn
# 30110                     Bothell
# 30111                     Seattle
# 30112                     Redmond
# 30113                      Renton
# 30114                     Seattle
# 30115                      Burien
# 30116                   Rochester
# 30117                     Seattle
# 30118                     Seattle
# 30119                      Burien
# 30120                     Seattle
# 30121                   Shoreline
# 30122                     Seattle
# 30123                     Seattle
# 30124                      Auburn
# 30125                      Burien
# 30126                    Kirkland
# 30127                    Bellevue
# 30128                 Federal Way
# 30129                Mount Laurel
# 30130               Mercer Island
# 30131                      Renton
# 30132                      Burien
# 30133                     Seattle
# 30134                      Auburn
# 30135                    Kirkland
# 30136                     Seattle
# 30137                   Shoreline
# 30138                     Redmond
# 30139                    Kirkland
# 30140                     Seattle
# 30141                     Seattle
# 30142                     Seattle
# 30143                     Seattle
# 30144                       Miami
# 30145                  North Bend
# 30146                      Auburn
# 30147                      Auburn
# 30148                      Duvall
# 30149                     Seattle
# 30150                     Seattle
# 30151                     Seattle
# 30152                     Seattle
# 30153                      Renton
# 30154                      Burien
# Name: city, dtype: object

# %% [markdown]
# ### Grabbing Zipcode

# %%
df['zipcode'] = df['address'].apply(lambda x: x.split(',')[2].split(' ')[-1])
df['zipcode'] = df['zipcode'].apply(lambda x: '97210' if 'Portland' in x\
                                    else '91730' if 'Cucamonga' in x\
                                    else '29582' if 'Beach' in x\
                                    else '34698' if 'Dunedin' in x\
                                    else '43210' if 'Columbus' in x\
                                   else '98126' if 'Seattle' in x\
                                   else '54002' if 'Baldwin'in x\
                                   else '78257' if 'Antonio' in x\
                                   else '02134' if 'Allston'in x\
                                   else '07031' if 'Arlington' in x\
                                   else '73118' if 'City' in x\
                                   else '94122' if 'Francisco' in x\
                                   else '02852' if 'Kingstown' in x\
                                   else '85705' if 'Tucson' in x\
                                   else x)

# %%
df[~df['zipcode'].str.startswith('98')]['zipcode']
# Out:
# 12       68106
# 53       08360
# 62       62859
# 159      07087
# 24961    68651
# 24965    53142
# 24966    55404
# 25001    60088
# 25040    07650
# 25053    58503
# 25054    91730
# 25165    96064
# 25180    66104
# 25199    68601
# 25231    07712
# 25262    63640
# 25298    45039
# 25314    99223
# 25317    11501
# 25396    91730
# 25433    80501
# 25454    55356
# 25455    07103
# 25467    02852
# 25479    63653
# 25524    68106
# 25538    55901
# 25587    58104
# 25643    97210
# 25656    97201
# 25725    08008
# 25800    64119
# 25842    52040
# 25883    80238
# 26045    54002
# 26073    68123
# 26091    68123
# 26129    01541
# 26147    91730
# 26340    80210
# 26374    61201
# 26496    18960
# 26563    55417
# 26585    69154
# 26601    80501
# 26629    63653
# 26630    46403
# 26672    33054
# 26735    47272
# 26786    68410
# 26797    68601
# 26807    91730
# 26874    64119
# 26886    11704
# 26887    46312
# 26942    55734
# 26943    43211
# 26946    43211
# 26947    67801
# 26948    67801
# 26949    43211
# 26977    47265
# 26985    63653
# 26995    62896
# 27023    53142
# 27099    68643
# 27166    63624
# 27215    07103
# 27238    68410
# 27271    80401
# 27372    52405
# 27378    68410
# 27444    60411
# 27497    55406
# 27504    50237
# 27508    68651
# 27548    08752
# 27626    49051
# 27712    68410
# 27731    97459
# 27785    49783
# 27792    07719
# 27802    68601
# 27844    11369
# 27872    99501
# 27904    02066
# 27915    58572
# 27930    95822
# 27958    96064
# 28038    61244
# 28058    07031
# 28080    52732
# 28109    97459
# 28113    68048
# 28145    08008
# 28148    15120
# 28213    62401
# 28219    02568
# 28220    68123
# 28225    11704
# 28245    68123
# 28256    02066
# 28306    08360
# 28368    11704
# 28381    93523
# 28383    91730
# 28394    68601
# 28463    02134
# 28475    43211
# 28492    47265
# 28511    64119
# 28533    68410
# 28578    08520
# 28596    11360
# 28632    53158
# 28633    55901
# 28653    07063
# 28664    11706
# 28701    91730
# 28820    53215
# 28840    58261
# 28976    43210
# 29091    02066
# 29117    84403
# 29144    11215
# 29150    96064
# 29162    56251
# 29234    46403
# 29270    55406
# 29429    55417
# 29472    68133
# 29515    73118
# 29534    65049
# 29556    08752
# 29631    94122
# 29723    85210
# 29788    08752
# 29793    63601
# 29806    97459
# 29814    53142
# 29858    58558
# 29869    15120
# 29900    34470
# 29978    25177
# 29980    61244
# 30019    60155
# 30022    68410
# 30029    07031
# 30044    53142
# 30116    55901
# 30129    08054
# 30144    33147
# Name: zipcode, dtype: object

# %%
df['address'][29515]
# Out:
# 'Avenue, 1710 Belle Isle Blvd, Oklahoma City, Oklahoma 73118, United States'

# %%
non_zips = ['Portland','Cucamonga','Beach','Dunedin','Columbus','Seattle','Baldwin','Antonio','Allston','Kingstown'\
           'Tucson','Arlington','City','Francisco']

bad_zips = df[df['zipcode'].isin(non_zips)]
# bad_zips['zipcode'].value_counts()

bad_zips['zipcode']
# Out:
# Series([], Name: zipcode, dtype: object)

# %%
df.groupby(['waterfront','zipcode'])['price'].mean().reset_index().sort_values('price',ascending=False)
# Out:
#      waterfront zipcode         price
# 442           1   98122  2.230000e+07
# 301           0   98002  4.718513e+05
# 380           0   98288  4.664417e+05
# 98            0   46403  4.656714e+05
# 55            0   15064  4.490000e+05
# 455           1   98288  4.297500e+05
# 246           0   70584  4.266660e+05
# 386           0   98422  3.127500e+05
# 422           1   98051  2.555000e+05
# 375           0   98224  2.546667e+05
# 185           0   60546  4.725000e+04

# %% [markdown]
# ## Eliminating Outliers

# %%
std_thresh = df.price.std()*3 # value of the third central moment of the target variable
df = df.loc[abs(df['price']) <= std_thresh] # slicing all data within the defined range

# # assign X and y variables to the appropriate dataframes/series
# y = outlier_eliminated_df.price
# X_outliers_eliminated = outlier_eliminated_df.drop('price',axis=1)

# %%
len(df)
# Out:
# 28897

# %%
df.corr()['price'].abs().sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.602011
# grade            0.576579
# sqft_above       0.517397
# bathrooms        0.462439
# bedrooms         0.332591
# sqft_patio       0.264555
# sqft_garage      0.259119
# view             0.216711
# sqft_basement    0.212435
# floors           0.206770
# sale_year        0.095691
# yr_built         0.090713
# sale_date        0.087849
# lat              0.082877
# sqft_lot         0.079134
# sale_month       0.073613
# yr_renovated     0.064861
# waterfront       0.041413
# long             0.027950
# condition        0.026328
# id               0.011473
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28897 entries, 0 to 30154
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             28897 non-null  int64
#  1   sale_date      28897 non-null  int64
#  2   price          28897 non-null  float64
#  3   bedrooms       28897 non-null  int64
#  4   bathrooms      28897 non-null  float64
#  5   sqft_living    28897 non-null  int64
#  6   sqft_lot       28897 non-null  int64
#  7   floors         28897 non-null  float64
#  8   waterfront     28897 non-null  int64
#  9   greenbelt      28897 non-null  object
#  10  nuisance       28897 non-null  object
#  11  view           28897 non-null  int64
#  12  condition      28897 non-null  int64
#  13  grade          28897 non-null  float64
#  14  heat_source    28897 non-null  object
#  15  sewer_system   28897 non-null  object
#  16  sqft_above     28897 non-null  int64
#  17  sqft_basement  28897 non-null  int64
#  18  sqft_garage    28897 non-null  int64
#  19  sqft_patio     28897 non-null  int64
#  20  yr_built       28897 non-null  int64
#  21  yr_renovated   28897 non-null  int64
#  22  address        28897 non-null  object
#  23  lat            28897 non-null  float64
#  24  long           28897 non-null  float64
#  25  sale_month     28897 non-null  int64
#  26  sale_year      28897 non-null  int64
#  27  city           28897 non-null  object
#  28  zipcode        28897 non-null  object
# dtypes: float64(6), int64(16), object(7)
# memory usage: 6.6+ MB

# %%
df['address'].head()
# Out:
# 0    2102 Southeast 21st Court, Renton, Washington ...
# 1    11231 Greenwood Avenue North, Seattle, Washing...
# 2    8504 South 113th Street, Seattle, Washington 9...
# 3    4079 Letitia Avenue South, Seattle, Washington...
# 4    2193 Northwest Talus Drive, Issaquah, Washingt...
# Name: address, dtype: object

# %% [markdown]
# ## Grabbing the City from the Address

# %%
df['City'] = df['address'].apply(lambda x: x.split(',')[1].strip())
df['City'].nunique()
# Out:
# 318

# %% [markdown]
# ## Print columns to begin search for predictors

# %%
df.columns
# Out:
# Index(['id', 'sale_date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'greenbelt', 'nuisance', 'view',
#        'condition', 'grade', 'heat_source', 'sewer_system', 'sqft_above',
#        'sqft_basement', 'sqft_garage', 'sqft_patio', 'yr_built',
#        'yr_renovated', 'address', 'lat', 'long', 'sale_month', 'sale_year',
#        'city', 'zipcode', 'City'],
#       dtype='object')

# %% [markdown]
# ## Check for correlations vs price for numerical variables

# %%
df.corr().sort_values('price',ascending=False)['price'].abs()
# Out:
# price            1.000000
# sqft_living      0.602011
# grade            0.576579
# sqft_above       0.517397
# bathrooms        0.462439
# bedrooms         0.332591
# sqft_patio       0.264555
# sqft_garage      0.259119
# view             0.216711
# sqft_basement    0.212435
# floors           0.206770
# sale_year        0.095691
# yr_built         0.090713
# sale_date        0.087849
# lat              0.082877
# sqft_lot         0.079134
# yr_renovated     0.064861
# waterfront       0.041413
# condition        0.026328
# id               0.011473
# long             0.027950
# sale_month       0.073613
# Name: price, dtype: float64

# %% [markdown]
# ## Looking at log transformations for the price.

# %%
df['price'].hist(bins=20);

sm.graphics.qqplot(df['price'],line='r');

# %% [markdown]
# As shown by the histogram of the price, we have a distribution that is heavily skewed right. The QQplot shows that the price follows an exponential pattern.

# %% [markdown]
# ## Using log transformation to normally distribute the price data

# %%
df['price_log'] = np.log(df['price'])

df['price_log'].hist();
sm.qqplot(df['price_log'], line='r');

# %% [markdown]
# ### Issue above is the data shows linearization everywhere but both tails of the data. Catching the lower tail will be the goal for the next test of transformation. For this, we will try a root transformation.

# %%
df['price_sqrt'] = df['price'] ** 0.5
df['price_sqrt'].hist();
sm.qqplot(df['price_sqrt'], line='r');

# %%
y_sqrt = df['price_sqrt']

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3)

og = sns.distplot(df['price'],ax=ax1).set_title('At baseline\n',fontsize=24)
ot = sns.distplot(y,ax=ax2).set_title('Eliminate extreme outliers\n',fontsize=24)
lo = sns.distplot(y_sqrt,ax=ax3).set_title('Square-root-transformation\n',fontsize=24)

ax1.set_ylabel("")
ax2.set_ylabel("")
ax3.set_ylabel("")


plt.gcf().set_size_inches(18, 8)
plt.suptitle("Target Variable Distribution Through Iterations",fontsize=32)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Now checking correlation of numerical values vs the transformed price

# %%
df = df.drop(['price_log'],axis='columns')

# %%
df.corr()['price_sqrt'].abs().sort_values(ascending=False)
# Out:
# price_sqrt       1.000000
# price            0.987192
# sqft_living      0.591597
# grade            0.574675
# sqft_above       0.505529
# bathrooms        0.465479
# bedrooms         0.332801
# sqft_patio       0.262311
# sqft_garage      0.254652
# sqft_basement    0.216284
# floors           0.216042
# view             0.207571
# yr_built         0.096788
# sale_year        0.095845
# sale_date        0.087454
# lat              0.079176
# sqft_lot         0.075319
# sale_month       0.074205
# yr_renovated     0.060367
# waterfront       0.037779
# condition        0.028102
# long             0.022053
# id               0.008427
# Name: price_sqrt, dtype: float64

# %% [markdown]
# Not much changes in terms of the correlations or the variables in order of correlation. We will look at the sqft_living aka Square footage of living space in the home as our first interesting variable based on the highest correlation.

# %% [markdown]
# ## Checking distribution of predictor

# %%
df['sqft_living'].hist();
sm.qqplot(df['sqft_living'], line='r');

# %% [markdown]
# Data is clearly skewed right and follows an exponential pattern similar to price. For this, we will use a logarithmic transformation.

# %%
df['sqft_living_log'] = np.log(df['sqft_living'])
df['sqft_living_log'].hist();
sm.qqplot(df['sqft_living_log'], line='r');

# %% [markdown]
# Sqft_living now shows an almost perfectly linear qqplot with the logarithmic transformation.

# %% [markdown]
# Data appears to be more normally distributed and shows better results on the QQplot.

# %% [markdown]
# ### Trying out a root transformation to see if there is any improvement.

# %%
df['sqft_living_sqrt'] = df['sqft_living']**0.5
df['sqft_living_sqrt'].hist();
sm.qqplot(df['sqft_living_sqrt'], line='r');

# %% [markdown]
# Square root transformation appears to be improving, so we will use it over the log transformation.

# %% [markdown]
# ## Building Preliminary model using the transformed sqft_living variable

# %%
X_baseline = df['sqft_living_sqrt']
y = df['price_sqrt']

model = sm.OLS(y, sm.add_constant(X_baseline))
results_baseline = model.fit()

# %%
baseline_resid = results_baseline.resid

# %%
sns.distplot(baseline_resid)
plt.suptitle("Baseline model reisdual distribution")
plt.show()

# %%
print(results_baseline.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                 1.517e+04
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:04:13   Log-Likelihood:            -1.9310e+05
# No. Observations:               28897   AIC:                         3.862e+05
# Df Residuals:                   28895   BIC:                         3.862e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              282.9228      5.632     50.235      0.000     271.884     293.962
# sqft_living_sqrt    15.4027      0.125    123.161      0.000      15.158      15.648
# ==============================================================================
# Omnibus:                      597.837   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1269.731
# Skew:                           0.073   Prob(JB):                    1.91e-276
# Kurtosis:                       4.017   Cond. No.                         223.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Preliminary model explains approximately 34.4% of the data according the the adjusted r-squared statistic.
# - sqft_living_log is a statistically significant variable as it shows a p-value under the 0.05 parameter

# %% [markdown]
# ## Adding in new variables

# %% [markdown]
# Checking the correlations again to search for more numerical variables

# %%
df.corr()['price'].abs().sort_values(ascending=False)
# Out:
# price               1.000000
# price_sqrt          0.987192
# sqft_living         0.602011
# sqft_living_sqrt    0.591360
# grade               0.576579
# sqft_living_log     0.565793
# sqft_above          0.517397
# bathrooms           0.462439
# bedrooms            0.332591
# sqft_patio          0.264555
# sqft_garage         0.259119
# view                0.216711
# sqft_basement       0.212435
# floors              0.206770
# sale_year           0.095691
# yr_built            0.090713
# sale_date           0.087849
# lat                 0.082877
# sqft_lot            0.079134
# sale_month          0.073613
# yr_renovated        0.064861
# waterfront          0.041413
# long                0.027950
# condition           0.026328
# id                  0.011473
# Name: price, dtype: float64

# %% [markdown]
# ### Next variable to try will be the grade as it is on the next highest list for correlation
# - Model will now have features consisting of the sqft_living_sqrt variable and the grade against the same dependent variable.
# - This will be known as X_NEW to avoid overlapping notation issues.
# - Similarly, NEW_model and NEW_results will be the new defined names with the addition of the grade.

# %%
df['grade'].value_counts()
# Out:
# 7.0     11643
# 8.0      9288
# 9.0      3546
# 6.0      2829
# 10.0      970
# 5.0       381
# 11.0      164
# 4.0        45
# 12.0       20
# 3.0         9
# 13.0        1
# 2.0         1
# Name: grade, dtype: int64

# %%
X_NEW = df[['sqft_living_sqrt','grade']]
y = df['price_sqrt']

NEW_model = sm.OLS(y, sm.add_constant(X_NEW))
NEW_results = NEW_model.fit()
print(NEW_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     9824.
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:04:15   Log-Likelihood:            -1.9170e+05
# No. Observations:               28897   AIC:                         3.834e+05
# Df Residuals:                   28894   BIC:                         3.834e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -36.1378      7.965     -4.537      0.000     -51.750     -20.526
# sqft_living_sqrt     9.6195      0.160     60.144      0.000       9.306       9.933
# grade               75.9099      1.400     54.204      0.000      73.165      78.655
# ==============================================================================
# Omnibus:                      939.314   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2499.056
# Skew:                           0.094   Prob(JB):                         0.00
# Kurtosis:                       4.428   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
r_squared_increase = str(round((NEW_results.rsquared - results_baseline.rsquared) * 100, 1)) + '%'
r_squared_increase
# Out:
# '6.1%'

# %% [markdown]
#  - NEW model explains approximately 40.3% of the data according the the adjusted r-squared statistic.
#  - sqft_living_sqrt is a statistically significant variable as it shows a p-value under the 0.05 parameter
#  - grade is a statistically significant variable as it shows a p-value under the 0.05 parameter
#  - Addition of the grade as an independent variable increased the model adj. r-squared by 6%

# %% [markdown]
# ## The next numerical variable to look at is the sqft_above aka Square footage of house apart from basement.
# - All new names will be repeated as we are adding in new numerical variables to see if they improve the model.
# - First we will look at the distribution of the sqft_above.

# %%
df['sqft_above'].hist();
sm.qqplot(df['sqft_above'], line='r');

# %% [markdown]
# ### Similar to the sqft_living variable, data appears skewed left and should be transformed before being added to the model.
# - First "try" will be a log transformation, followed again by a root transformation.

# %%
df['sqft_above_log'] = np.log(df['sqft_above'])

df['sqft_above_log'].hist();
sm.qqplot(df['sqft_above_log'], line='r');

# %% [markdown]
# Similarly as before with the sqft_living variable, the log transformation appears to be normally distributed now. Time to add the variable to the model to see if it improves.

# %%
X_NEW = df[['sqft_living_sqrt','grade', 'sqft_above_log']]
y = df['price_sqrt']

NEW_model = sm.OLS(y, sm.add_constant(X_NEW))
NEW_results = NEW_model.fit()
print(NEW_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     6688.
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:04:19   Log-Likelihood:            -1.9158e+05
# No. Observations:               28897   AIC:                         3.832e+05
# Df Residuals:                   28893   BIC:                         3.832e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              385.1526     27.931     13.789      0.000     330.406     439.899
# sqft_living_sqrt    12.4740      0.241     51.665      0.000      12.001      12.947
# grade               80.0209      1.419     56.401      0.000      77.240      82.802
# sqft_above_log     -78.4620      4.988    -15.731      0.000     -88.238     -68.686
# ==============================================================================
# Omnibus:                      982.804   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2700.107
# Skew:                           0.091   Prob(JB):                         0.00
# Kurtosis:                       4.486   Cond. No.                     1.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# No meaningful change has been made to the model with the sqft_above variable being added, so it will be left out. Time to look at the other numerical variables to see if any of them can possibly be used to add to the model itself.

# %%
numerical_candidates = df[['sqft_living','grade','sqft_above','bathrooms','sqft_patio','bedrooms',\
                           'sqft_garage','sqft_basement']]

y = df['price_sqrt']

numerical_candidates_model = sm.OLS(y, sm.add_constant(numerical_candidates))
numerical_candidates_results = numerical_candidates_model.fit()
print(numerical_candidates_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     2693.
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:55:10   Log-Likelihood:            -1.9115e+05
# No. Observations:               28897   AIC:                         3.823e+05
# Df Residuals:                   28888   BIC:                         3.824e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           144.3210      9.797     14.731      0.000     125.118     163.524
# sqft_living       0.0647      0.005     12.734      0.000       0.055       0.075
# grade            80.6657      1.491     54.110      0.000      77.744      83.588
# sqft_above        0.0508      0.005     10.109      0.000       0.041       0.061
# bathrooms         2.8944      2.034      1.423      0.155      -1.093       6.882
# sqft_patio        0.0319      0.005      6.421      0.000       0.022       0.042
# bedrooms         -7.3680      1.512     -4.874      0.000     -10.331      -4.405
# sqft_garage      -0.0935      0.005    -19.908      0.000      -0.103      -0.084
# sqft_basement     0.0652      0.004     17.912      0.000       0.058       0.072
# ==============================================================================
# Omnibus:                     1154.278   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3661.533
# Skew:                           0.053   Prob(JB):                         0.00
# Kurtosis:                       4.741   Cond. No.                     2.76e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Since the sqft_above variable follows the same distribution as the sqft_living variable, it stands to reason that adding in other numerical variables with a similar distribution will also not improve the model. The only variable that does NOT appear to be skewed right along with the rest of the data is the bedrooms. This is the last numerical variable we will test.

# %%
df['bedrooms'].hist();
sm.qqplot(df['bedrooms'], line='r');

# %%
X_NEW = df[['sqft_living_sqrt','grade', 'bedrooms']]
y = df['price_sqrt']

NEW_model = sm.OLS(y, sm.add_constant(X_NEW))
NEW_results = NEW_model.fit()
print(NEW_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     6572.
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:04:24   Log-Likelihood:            -1.9168e+05
# No. Observations:               28897   AIC:                         3.834e+05
# Df Residuals:                   28893   BIC:                         3.834e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -25.8153      8.120     -3.179      0.001     -41.731      -9.900
# sqft_living_sqrt    10.4517      0.206     50.806      0.000      10.048      10.855
# grade               74.1085      1.427     51.923      0.000      71.311      76.906
# bedrooms            -9.8812      1.538     -6.425      0.000     -12.895      -6.867
# ==============================================================================
# Omnibus:                      942.713   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2520.232
# Skew:                           0.091   Prob(JB):                         0.00
# Kurtosis:                       4.435   Cond. No.                         347.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Once again, bedrooms as an added variable does not improve the rsquared in the model, so it will be left out. This ends our exploration of the numerical variables!

# %% [markdown]
# ## Attempting interactions to improve model

# %%
df.corr()['price_sqrt'].abs().sort_values(ascending=False)
# Out:
# price_sqrt          1.000000
# price               0.987192
# sqft_living         0.591597
# sqft_living_sqrt    0.586722
# grade               0.574675
# sqft_living_log     0.567022
# sqft_above          0.505529
# sqft_above_log      0.490600
# bathrooms           0.465479
# bedrooms            0.332801
# sqft_patio          0.262311
# sqft_garage         0.254652
# sqft_basement       0.216284
# floors              0.216042
# view                0.207571
# yr_built            0.096788
# sale_year           0.095845
# sale_date           0.087454
# lat                 0.079176
# sqft_lot            0.075319
# sale_month          0.074205
# yr_renovated        0.060367
# waterfront          0.037779
# condition           0.028102
# long                0.022053
# id                  0.008427
# Name: price_sqrt, dtype: float64

# %% [markdown]
# - This interaction creates an almost perfectly linear plot.

# %% [markdown]
# # Adding in Categorical variables

# %%
df.columns
# Out:
# Index(['id', 'sale_date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'greenbelt', 'nuisance', 'view',
#        'condition', 'grade', 'heat_source', 'sewer_system', 'sqft_above',
#        'sqft_basement', 'sqft_garage', 'sqft_patio', 'yr_built',
#        'yr_renovated', 'address', 'lat', 'long', 'sale_month', 'sale_year',
#        'city', 'zipcode', 'City', 'price_sqrt', 'sqft_living_log',
#        'sqft_living_sqrt', 'sqft_above_log'],
#       dtype='object')

# %% [markdown]
# ## Getting categorical candidates

# %%
categorical_candidates = df[['sale_date','bathrooms','bedrooms','floors','waterfront','greenbelt',\
                             'nuisance','view','condition','grade','heat_source','sewer_system',\
                             'yr_renovated','address','lat','long','City']]

# %%
categorical_candidates_price = pd.concat([categorical_candidates, df['price_sqrt']], axis='columns')

# %%
categorical_candidates_price.plot.scatter(x='view',y='price_sqrt')
plt.xticks(rotation=45)
plt.show()

# %%
df_.columns
# Out:
# Index(['sqft_living_sqrt', 'grade', 'view', 'bathrooms', 'waterfront'], dtype='object')

# %%
X_final = df[['sqft_living_sqrt','grade']]
y = df['price_sqrt']

final_model = sm.OLS(y, sm.add_constant(X_final))
final_results = final_model.fit()
print(final_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_sqrt   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     9824.
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:04:31   Log-Likelihood:            -1.9170e+05
# No. Observations:               28897   AIC:                         3.834e+05
# Df Residuals:                   28894   BIC:                         3.834e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -36.1378      7.965     -4.537      0.000     -51.750     -20.526
# sqft_living_sqrt     9.6195      0.160     60.144      0.000       9.306       9.933
# grade               75.9099      1.400     54.204      0.000      73.165      78.655
# ==============================================================================
# Omnibus:                      939.314   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2499.056
# Skew:                           0.094   Prob(JB):                         0.00
# Kurtosis:                       4.428   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
final_resid = final_results.resid

# %%
sns.distplot(final_resid)
plt.suptitle("Final model reisdual distribution")
plt.show()

# %%
r_squared_increase = str(round((final_results.rsquared - NEW_results.rsquared) * 100, 1)) + '%'
r_squared_increase
# Out:
# '-0.1%'

# %% [markdown]
# - Final model explains approximately 47.9% of the data according the the adjusted r-squared statistic.
# - sqft_living_log is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - grade is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - view_EXCELLENT is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - view_FAIR is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - view_GOOD is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - view_AVERAGE is a statistically significant variable as it shows a p-value under the 0.05 parameter
# - Addition of the grade as an independent variable increased the model adj. r-squared by 3.8%

# %%
dummies = pd.get_dummies(df['sale_month','sale_date','waterfront','condition',], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sale_month', 'sale_date', 'waterfront', 'condition')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/723931676.py in <module>
# ----> 1 dummies = pd.get_dummies(df['sale_month','sale_date','waterfront','condition',], drop_first=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ('sale_month', 'sale_date', 'waterfront', 'condition')

# %%
water_front = df['waterfront']
lat = df['lat']
long = df['long']
view = df['view']


bathrooms = df['bathrooms']
X_final_zipcodes = pd.concat([dummies,X_final,water_front,lat,long, view,condition, sale_date,bathrooms],axis='columns')
X_final_zipcodes = (X_final_zipcodes - np.mean(X_final_zipcodes)) / np.std(X_final_zipcodes)

# %%
y = df['price_sqrt']

final_model = sm.OLS(y, sm.add_constant(X_final_zipcodes))
final_results = final_model.fit()
print(final_results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10620/4126802948.py in <module>
#       1 y = df['price_sqrt']
#       2
# ----> 3 final_model = sm.OLS(y, sm.add_constant(X_final_zipcodes))
#       4 final_results = final_model.fit()
#       5 print(final_results.summary())
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# --> 703         super(WLS, self).__init__(endog, exog, missing=missing,
#     704                                   weights=weights, hasconst=hasconst, **kwargs)
#     705         nobs = self.exog.shape[0]
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'weights'])
#     192
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      85         self.const_idx = None
#      86         self.k_constant = 0
# ---> 87         self._handle_constant(hasconst)
#      88         self._check_integrity()
#      89         self._cache = {}
#
# ~\anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             exog_max = np.max(self.exog, axis=0)
#     132             if not np.isfinite(exog_max).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             exog_min = np.min(self.exog, axis=0)
#     135             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans
